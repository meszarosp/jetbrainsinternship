# %% [markdown]
# # Prediction of reactions to the posts
# # Task 2
# The notebook was made and tested on Google Colab

# %% [markdown]
# ## Install dependencies
#
# Installing all the dependencies using pip

# %%
# !pip install gdown > /dev/null
# !pip install pandas > /dev/null
# !pip install numpy > /dev/null
# !pip install torch torchtext > /dev/null

# %% [markdown]
# ## Imports
#
# Importing torch and other utility libraries

# %%
import gdown
import pandas as pd
import numpy as np

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from torch.utils.data import TensorDataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence

# %% [markdown]
# ## Download and prepare data
#
# Download the dataset, then read it using Pandas.
# Splitting the data into train, val, test.

# %%
# The given URL is transformed
# https://drive.google.com/file/d/10CvDP3AFOTYmoXhWXLRDm6n_XSZV6Yev/view?usp=sharing
# Download dataset
URL = "https://drive.google.com/uc?id=10CvDP3AFOTYmoXhWXLRDm6n_XSZV6Yev"
datafile = "dataset.csv"
gdown.download(URL, datafile, quiet=True)
df = pd.read_csv(datafile)

# %%
# Counting classes and reading the dataset

classes = pd.unique(df['Label'])
N_classes = len(classes)
df['Label'] = df['Label'].replace(classes, np.arange(N_classes, dtype=int))
text = df['FBPost'].to_numpy()
labels = torch.tensor(df['Label'].values)

# %%
#Look at the distribution of the labels
df.groupby(["Label"]).count()
# Out:
#        Unnamed: 0  FBPost
# Label
# 0             280     280
# 1              79      79
# 2             641     641

# %% [markdown]
# ### Define some important functions

# %%
def shuffle_dataset(text, labels):
  p = np.random.permutation(text.shape[0])
  return text[p], labels[p]

# %%
def split_dataset(text, labels, train_split, val_split):
  N_data = text.shape[0]

  train_split = int(N_data * 0.7)
  val_split = int(N_data * (0.7+0.15))

  # Split
  train_sentences = text[0:train_split]
  train_labels = labels[0:train_split]
  val_sentences = text[train_split:val_split]
  val_labels = labels[train_split:val_split]
  test_sentences = text[val_split:]
  test_labels = labels[val_split:]

  return train_sentences, train_labels, val_sentences, val_labels, test_sentences, test_labels

# %%
def token_iterator(dataset, tokenizer):
    for sentence in dataset:
        yield tokenizer(str(text))

# %%
def build_vocab(sentences):
  tokenizer = get_tokenizer('basic_english')
  vocab = build_vocab_from_iterator(token_iterator(sentences, tokenizer), specials=["<UNK>"])
  vocab.set_default_index(vocab["<UNK>"])
  vocab.append_token("<PAD>")
  pad_index = vocab["<PAD>"]
  return tokenizer, vocab, pad_index

# %%
def truncate_or_pad(sentence, max_len, pad_index):
  if len(sentence) > max_len:
    return sentence[0:max_len]
  else:
    return F.pad(sentence, (0, max_len-len(sentence)),'constant', pad_index)

# %% [markdown]
# ### Create datasets

# %%
#Shuffle and split dataset, then build a vocabulary from tokenized sentences
text, labels = shuffle_dataset(text, labels)
train_sentences, train_labels, val_sentences, val_labels, test_sentences, test_labels = split_dataset(text, labels, 0.7, 0.15)
tokenizer, vocab, pad_index = build_vocab(train_sentences)

# %%
MAX_LEN = 300
#Pad the sentences to max length (or truncate them if they are longer) and stack them into a tensor
train_vectorized = torch.stack([truncate_or_pad(torch.tensor(vocab.forward(tokenizer(sentence))), MAX_LEN, pad_index) for sentence in train_sentences])
val_vectorized = torch.stack([truncate_or_pad(torch.tensor(vocab.forward(tokenizer(sentence))), MAX_LEN, pad_index) for sentence in val_sentences])
test_vectorized = torch.stack([truncate_or_pad(torch.tensor(vocab.forward(tokenizer(sentence))), MAX_LEN, pad_index) for sentence in test_sentences])

# %%
#Create dataloaders for each dataset
BATCH_SIZE = 50

train = DataLoader(TensorDataset(train_vectorized, train_labels), batch_size=BATCH_SIZE, shuffle=True)
val = DataLoader(TensorDataset(val_vectorized, val_labels), batch_size=BATCH_SIZE, shuffle=True)
test = DataLoader(TensorDataset(test_vectorized, test_labels), batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# ## Model

# %%
class SentenceClassifier(nn.Module):
  def __init__(self, embedding_dimension, hidden_dimension, vocabulary_size, number_of_classes, pad_index):
    super(SentenceClassifier, self).__init__()
    self.pad_index = pad_index

    self.embedding = nn.Embedding(vocabulary_size, embedding_dimension)
    self.lstm = nn.LSTM(embedding_dimension, hidden_dimension, batch_first=True)
    self.last = nn.Linear(hidden_dimension, number_of_classes)

  def forward(self, sentences):
    embeddings = self.embedding(sentences)
    lstm_out, _ = self.lstm(embeddings)

    lengths = (MAX_LEN - (sentences == self.pad_index).sum(dim=1)) -1
    last_values = self.last(lstm_out[range(0, sentences.size()[0]), lengths, :])
    class_scores = F.log_softmax(last_values, dim=1)

    return class_scores

# %%
EMBEDDING_DIM = 128
HIDDEN_DIM = 64
VOCABULARY_SIZE = len(vocab)

model = SentenceClassifier(EMBEDDING_DIM,HIDDEN_DIM,VOCABULARY_SIZE, N_classes, pad_index)
loss_function = nn.NLLLoss()
val_loss_function = nn.NLLLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001)

# %%
print(model)
# Out:
# SentenceClassifier(
#   (embedding): Embedding(3003, 128)
#   (lstm): LSTM(128, 64, batch_first=True)
#   (last): Linear(in_features=64, out_features=3, bias=True)
# )

# %%
class EarlyStopping:
  def __init__(self, patience=1, min_delta=0):
    self.patience = patience
    self.min_delta = min_delta
    self.counter = 0
    self.val_loss = np.inf

  def early_stop(self, val_loss):
    if val_loss < self.val_loss:
      self.val_loss = val_loss
      self.counter = 0
    elif val_loss > (self.val_loss + self.min_delta):
      self.counter += 1
    if self.counter >= self.patience:
      return True
    return False

# %%
EPOCHS = 100

early_stopper = EarlyStopping(10, 0.01)

for epoch in range(EPOCHS):
  running_loss = 0
  correct_predictions = 0
  total_step = len(train)
  for index, (sentences, labels) in enumerate(train):
    model.zero_grad()

    class_scores = model(sentences)

    loss = loss_function(class_scores, labels)
    loss.backward()
    optimizer.step()
    running_loss += loss.item()
    correct_predictions +=(torch.argmax(class_scores, dim=1) == labels).sum()
    if index % 2 == 0:
      print(f'[EPOCH: {epoch + 1}/{EPOCHS}, STEP:{index+1}/{total_step}] loss: {running_loss/5:.3f}')
      running_loss = 0

    #Early stopping
    with torch.no_grad():
      val_loss = 0
      for sentences, labels in val:
        class_scores = model(sentences)
        val_loss += val_loss_function(class_scores, labels)
      if early_stopper.early_stop(val_loss):
        break
  print(f'[EPOCH: {epoch + 1}/{EPOCHS}] accuracy: {correct_predictions/len(train.dataset):.3f} val_loss: {val_loss:.3f}')
  print("---------------------------------------------")
# Out:
# [EPOCH: 1/100, STEP:1/14] loss: 0.219
# [EPOCH: 1/100, STEP:3/14] loss: 0.438
# [EPOCH: 1/100, STEP:5/14] loss: 0.442
# [EPOCH: 1/100, STEP:7/14] loss: 0.442
# [EPOCH: 1/100, STEP:9/14] loss: 0.445
# [EPOCH: 1/100, STEP:11/14] loss: 0.442
# [EPOCH: 1/100, STEP:13/14] loss: 0.445
# [EPOCH: 1/100] accuracy: 0.324 val_loss: 3.296
# ---------------------------------------------
# [EPOCH: 2/100, STEP:1/14] loss: 0.217
# [EPOCH: 2/100, STEP:3/14] loss: 0.441
# [EPOCH: 2/100, STEP:5/14] loss: 0.441
# [EPOCH: 2/100, STEP:7/14] loss: 0.437
# [EPOCH: 2/100, STEP:9/14] loss: 0.442
# [EPOCH: 2/100, STEP:11/14] loss: 0.436
# [EPOCH: 2/100, STEP:13/14] loss: 0.444
# [EPOCH: 2/100] accuracy: 0.346 val_loss: 3.277
# ---------------------------------------------
# [EPOCH: 3/100, STEP:1/14] loss: 0.216
# [EPOCH: 3/100, STEP:3/14] loss: 0.436
# [EPOCH: 3/100, STEP:5/14] loss: 0.438
# [EPOCH: 3/100, STEP:7/14] loss: 0.431
# [EPOCH: 3/100, STEP:9/14] loss: 0.442
# [EPOCH: 3/100, STEP:11/14] loss: 0.441
# [EPOCH: 3/100, STEP:13/14] loss: 0.439
# [EPOCH: 3/100] accuracy: 0.376 val_loss: 3.258
# ---------------------------------------------
# [EPOCH: 4/100, STEP:1/14] loss: 0.223
# [EPOCH: 4/100, STEP:3/14] loss: 0.435
# [EPOCH: 4/100, STEP:5/14] loss: 0.439
# [EPOCH: 4/100, STEP:7/14] loss: 0.432
# [EPOCH: 4/100, STEP:9/14] loss: 0.433
# [EPOCH: 4/100, STEP:11/14] loss: 0.437
# [EPOCH: 4/100, STEP:13/14] loss: 0.429
# [EPOCH: 4/100] accuracy: 0.406 val_loss: 3.239
# ---------------------------------------------
# [EPOCH: 5/100, STEP:1/14] loss: 0.215
# [EPOCH: 5/100, STEP:3/14] loss: 0.433
# [EPOCH: 5/100, STEP:5/14] loss: 0.432
# [EPOCH: 5/100, STEP:7/14] loss: 0.431
# [EPOCH: 5/100, STEP:9/14] loss: 0.429
# [EPOCH: 5/100, STEP:11/14] loss: 0.436
# [EPOCH: 5/100, STEP:13/14] loss: 0.431
# [EPOCH: 5/100] accuracy: 0.449 val_loss: 3.221
# ---------------------------------------------
# [EPOCH: 6/100, STEP:1/14] loss: 0.216
# [EPOCH: 6/100, STEP:3/14] loss: 0.432
# [EPOCH: 6/100, STEP:5/14] loss: 0.431
# [EPOCH: 6/100, STEP:7/14] loss: 0.428
# [EPOCH: 6/100, STEP:9/14] loss: 0.433
# [EPOCH: 6/100, STEP:11/14] loss: 0.431
# [EPOCH: 6/100, STEP:13/14] loss: 0.424
# [EPOCH: 6/100] accuracy: 0.500 val_loss: 3.204
# ---------------------------------------------
# [EPOCH: 7/100, STEP:1/14] loss: 0.212
# [EPOCH: 7/100, STEP:3/14] loss: 0.423
# [EPOCH: 7/100, STEP:5/14] loss: 0.427
# [EPOCH: 7/100, STEP:7/14] loss: 0.432
# [EPOCH: 7/100, STEP:9/14] loss: 0.428
# [EPOCH: 7/100, STEP:11/14] loss: 0.426
# [EPOCH: 7/100, STEP:13/14] loss: 0.434
# [EPOCH: 7/100] accuracy: 0.553 val_loss: 3.187
# ---------------------------------------------
# [EPOCH: 8/100, STEP:1/14] loss: 0.216
# [EPOCH: 8/100, STEP:3/14] loss: 0.425
# [EPOCH: 8/100, STEP:5/14] loss: 0.424
# [EPOCH: 8/100, STEP:7/14] loss: 0.427
# [EPOCH: 8/100, STEP:9/14] loss: 0.425
# [EPOCH: 8/100, STEP:11/14] loss: 0.422
# [EPOCH: 8/100, STEP:13/14] loss: 0.425
# [EPOCH: 8/100] accuracy: 0.570 val_loss: 3.170
# ---------------------------------------------
# [EPOCH: 9/100, STEP:1/14] loss: 0.217
# [EPOCH: 9/100, STEP:3/14] loss: 0.417
# [EPOCH: 9/100, STEP:5/14] loss: 0.425
# [EPOCH: 9/100, STEP:7/14] loss: 0.425
# [EPOCH: 9/100, STEP:9/14] loss: 0.417
# [EPOCH: 9/100, STEP:11/14] loss: 0.429
# [EPOCH: 9/100, STEP:13/14] loss: 0.420
# [EPOCH: 9/100] accuracy: 0.587 val_loss: 3.153
# ---------------------------------------------
# [EPOCH: 10/100, STEP:1/14] loss: 0.215
# [EPOCH: 10/100, STEP:3/14] loss: 0.423
# [EPOCH: 10/100, STEP:5/14] loss: 0.417
# [EPOCH: 10/100, STEP:7/14] loss: 0.422
# [EPOCH: 10/100, STEP:9/14] loss: 0.418
# [EPOCH: 10/100, STEP:11/14] loss: 0.418
# [EPOCH: 10/100, STEP:13/14] loss: 0.425
# [EPOCH: 10/100] accuracy: 0.594 val_loss: 3.137
# ---------------------------------------------
# [EPOCH: 11/100, STEP:1/14] loss: 0.210
# [EPOCH: 11/100, STEP:3/14] loss: 0.415
# [EPOCH: 11/100, STEP:5/14] loss: 0.423
# [EPOCH: 11/100, STEP:7/14] loss: 0.417
# [EPOCH: 11/100, STEP:9/14] loss: 0.422
# [EPOCH: 11/100, STEP:11/14] loss: 0.428
# [EPOCH: 11/100, STEP:13/14] loss: 0.414
# [EPOCH: 11/100] accuracy: 0.601 val_loss: 3.122
# ---------------------------------------------
# [EPOCH: 12/100, STEP:1/14] loss: 0.210
# [EPOCH: 12/100, STEP:3/14] loss: 0.422
# [EPOCH: 12/100, STEP:5/14] loss: 0.422
# [EPOCH: 12/100, STEP:7/14] loss: 0.420
# [EPOCH: 12/100, STEP:9/14] loss: 0.413
# [EPOCH: 12/100, STEP:11/14] loss: 0.419
# [EPOCH: 12/100, STEP:13/14] loss: 0.410
# [EPOCH: 12/100] accuracy: 0.601 val_loss: 3.106
# ---------------------------------------------
# [EPOCH: 13/100, STEP:1/14] loss: 0.212
# [EPOCH: 13/100, STEP:3/14] loss: 0.410
# [EPOCH: 13/100, STEP:5/14] loss: 0.425
# [EPOCH: 13/100, STEP:7/14] loss: 0.420
# [EPOCH: 13/100, STEP:9/14] loss: 0.415
# [EPOCH: 13/100, STEP:11/14] loss: 0.413
# [EPOCH: 13/100, STEP:13/14] loss: 0.414
# [EPOCH: 13/100] accuracy: 0.603 val_loss: 3.092
# ---------------------------------------------
# [EPOCH: 14/100, STEP:1/14] loss: 0.202
# [EPOCH: 14/100, STEP:3/14] loss: 0.407
# [EPOCH: 14/100, STEP:5/14] loss: 0.414
# [EPOCH: 14/100, STEP:7/14] loss: 0.429
# [EPOCH: 14/100, STEP:9/14] loss: 0.418
# [EPOCH: 14/100, STEP:11/14] loss: 0.404
# [EPOCH: 14/100, STEP:13/14] loss: 0.417
# [EPOCH: 14/100] accuracy: 0.603 val_loss: 3.077
# ---------------------------------------------
# [EPOCH: 15/100, STEP:1/14] loss: 0.208
# [EPOCH: 15/100, STEP:3/14] loss: 0.418
# [EPOCH: 15/100, STEP:5/14] loss: 0.416
# [EPOCH: 15/100, STEP:7/14] loss: 0.410
# [EPOCH: 15/100, STEP:9/14] loss: 0.406
# [EPOCH: 15/100, STEP:11/14] loss: 0.419
# [EPOCH: 15/100, STEP:13/14] loss: 0.412
# [EPOCH: 15/100] accuracy: 0.604 val_loss: 3.063
# ---------------------------------------------
# [EPOCH: 16/100, STEP:1/14] loss: 0.204
# [EPOCH: 16/100, STEP:3/14] loss: 0.413
# [EPOCH: 16/100, STEP:5/14] loss: 0.395
# [EPOCH: 16/100, STEP:7/14] loss: 0.415
# [EPOCH: 16/100, STEP:9/14] loss: 0.415
# [EPOCH: 16/100, STEP:11/14] loss: 0.413
# [EPOCH: 16/100, STEP:13/14] loss: 0.409
# [EPOCH: 16/100] accuracy: 0.604 val_loss: 3.050
# ---------------------------------------------
# [EPOCH: 17/100, STEP:1/14] loss: 0.203
# [EPOCH: 17/100, STEP:3/14] loss: 0.414
# [EPOCH: 17/100, STEP:5/14] loss: 0.406
# [EPOCH: 17/100, STEP:7/14] loss: 0.410
# [EPOCH: 17/100, STEP:9/14] loss: 0.414
# [EPOCH: 17/100, STEP:11/14] loss: 0.400
# [EPOCH: 17/100, STEP:13/14] loss: 0.405
# [EPOCH: 17/100] accuracy: 0.606 val_loss: 3.036
# ---------------------------------------------
# [EPOCH: 18/100, STEP:1/14] loss: 0.201
# [EPOCH: 18/100, STEP:3/14] loss: 0.411
# [EPOCH: 18/100, STEP:5/14] loss: 0.404
# [EPOCH: 18/100, STEP:7/14] loss: 0.406
# [EPOCH: 18/100, STEP:9/14] loss: 0.410
# [EPOCH: 18/100, STEP:11/14] loss: 0.407
# [EPOCH: 18/100, STEP:13/14] loss: 0.406
# [EPOCH: 18/100] accuracy: 0.607 val_loss: 3.023
# ---------------------------------------------
# [EPOCH: 19/100, STEP:1/14] loss: 0.203
# [EPOCH: 19/100, STEP:3/14] loss: 0.421
# [EPOCH: 19/100, STEP:5/14] loss: 0.417
# [EPOCH: 19/100, STEP:7/14] loss: 0.397
# [EPOCH: 19/100, STEP:9/14] loss: 0.397
# [EPOCH: 19/100, STEP:11/14] loss: 0.406
# [EPOCH: 19/100, STEP:13/14] loss: 0.402
# [EPOCH: 19/100] accuracy: 0.610 val_loss: 3.011
# ---------------------------------------------
# [EPOCH: 20/100, STEP:1/14] loss: 0.202
# [EPOCH: 20/100, STEP:3/14] loss: 0.401
# [EPOCH: 20/100, STEP:5/14] loss: 0.409
# [EPOCH: 20/100, STEP:7/14] loss: 0.405
# [EPOCH: 20/100, STEP:9/14] loss: 0.408
# [EPOCH: 20/100, STEP:11/14] loss: 0.397
# [EPOCH: 20/100, STEP:13/14] loss: 0.410
# [EPOCH: 20/100] accuracy: 0.613 val_loss: 2.999
# ---------------------------------------------
# [EPOCH: 21/100, STEP:1/14] loss: 0.198
# [EPOCH: 21/100, STEP:3/14] loss: 0.395
# [EPOCH: 21/100, STEP:5/14] loss: 0.402
# [EPOCH: 21/100, STEP:7/14] loss: 0.410
# [EPOCH: 21/100, STEP:9/14] loss: 0.410
# [EPOCH: 21/100, STEP:11/14] loss: 0.387
# [EPOCH: 21/100, STEP:13/14] loss: 0.415
# [EPOCH: 21/100] accuracy: 0.616 val_loss: 2.987
# ---------------------------------------------
# [EPOCH: 22/100, STEP:1/14] loss: 0.203
# [EPOCH: 22/100, STEP:3/14] loss: 0.399
# [EPOCH: 22/100, STEP:5/14] loss: 0.410
# [EPOCH: 22/100, STEP:7/14] loss: 0.392
# [EPOCH: 22/100, STEP:9/14] loss: 0.403
# [EPOCH: 22/100, STEP:11/14] loss: 0.402
# [EPOCH: 22/100, STEP:13/14] loss: 0.387
# [EPOCH: 22/100] accuracy: 0.616 val_loss: 2.975
# ---------------------------------------------
# [EPOCH: 23/100, STEP:1/14] loss: 0.210
# [EPOCH: 23/100, STEP:3/14] loss: 0.395
# [EPOCH: 23/100, STEP:5/14] loss: 0.388
# [EPOCH: 23/100, STEP:7/14] loss: 0.405
# [EPOCH: 23/100, STEP:9/14] loss: 0.389
# [EPOCH: 23/100, STEP:11/14] loss: 0.398
# [EPOCH: 23/100, STEP:13/14] loss: 0.414
# [EPOCH: 23/100] accuracy: 0.617 val_loss: 2.964
# ---------------------------------------------
# [EPOCH: 24/100, STEP:1/14] loss: 0.202
# [EPOCH: 24/100, STEP:3/14] loss: 0.396
# [EPOCH: 24/100, STEP:5/14] loss: 0.404
# [EPOCH: 24/100, STEP:7/14] loss: 0.397
# [EPOCH: 24/100, STEP:9/14] loss: 0.402
# [EPOCH: 24/100, STEP:11/14] loss: 0.394
# [EPOCH: 24/100, STEP:13/14] loss: 0.397
# [EPOCH: 24/100] accuracy: 0.619 val_loss: 2.953
# ---------------------------------------------
# [EPOCH: 25/100, STEP:1/14] loss: 0.199
# [EPOCH: 25/100, STEP:3/14] loss: 0.406
# [EPOCH: 25/100, STEP:5/14] loss: 0.390
# [EPOCH: 25/100, STEP:7/14] loss: 0.408
# [EPOCH: 25/100, STEP:9/14] loss: 0.393
# [EPOCH: 25/100, STEP:11/14] loss: 0.404
# [EPOCH: 25/100, STEP:13/14] loss: 0.389
# [EPOCH: 25/100] accuracy: 0.619 val_loss: 2.943
# ---------------------------------------------
# [EPOCH: 26/100, STEP:1/14] loss: 0.206
# [EPOCH: 26/100, STEP:3/14] loss: 0.396
# [EPOCH: 26/100, STEP:5/14] loss: 0.394
# [EPOCH: 26/100, STEP:7/14] loss: 0.400
# [EPOCH: 26/100, STEP:9/14] loss: 0.398
# [EPOCH: 26/100, STEP:11/14] loss: 0.389
# [EPOCH: 26/100, STEP:13/14] loss: 0.389
# [EPOCH: 26/100] accuracy: 0.620 val_loss: 2.933
# ---------------------------------------------
# [EPOCH: 27/100, STEP:1/14] loss: 0.201
# [EPOCH: 27/100, STEP:3/14] loss: 0.389
# [EPOCH: 27/100, STEP:5/14] loss: 0.381
# [EPOCH: 27/100, STEP:7/14] loss: 0.398
# [EPOCH: 27/100, STEP:9/14] loss: 0.408
# [EPOCH: 27/100, STEP:11/14] loss: 0.406
# [EPOCH: 27/100, STEP:13/14] loss: 0.395
# [EPOCH: 27/100] accuracy: 0.620 val_loss: 2.922
# ---------------------------------------------
# [EPOCH: 28/100, STEP:1/14] loss: 0.193
# [EPOCH: 28/100, STEP:3/14] loss: 0.389
# [EPOCH: 28/100, STEP:5/14] loss: 0.401
# [EPOCH: 28/100, STEP:7/14] loss: 0.402
# [EPOCH: 28/100, STEP:9/14] loss: 0.383
# [EPOCH: 28/100, STEP:11/14] loss: 0.383
# [EPOCH: 28/100, STEP:13/14] loss: 0.400
# [EPOCH: 28/100] accuracy: 0.621 val_loss: 2.913
# ---------------------------------------------
# [EPOCH: 29/100, STEP:1/14] loss: 0.185
# [EPOCH: 29/100, STEP:3/14] loss: 0.384
# [EPOCH: 29/100, STEP:5/14] loss: 0.397
# [EPOCH: 29/100, STEP:7/14] loss: 0.389
# [EPOCH: 29/100, STEP:9/14] loss: 0.406
# [EPOCH: 29/100, STEP:11/14] loss: 0.394
# [EPOCH: 29/100, STEP:13/14] loss: 0.401
# [EPOCH: 29/100] accuracy: 0.621 val_loss: 2.903
# ---------------------------------------------
# [EPOCH: 30/100, STEP:1/14] loss: 0.188
# [EPOCH: 30/100, STEP:3/14] loss: 0.386
# [EPOCH: 30/100, STEP:5/14] loss: 0.397
# [EPOCH: 30/100, STEP:7/14] loss: 0.395
# [EPOCH: 30/100, STEP:9/14] loss: 0.389
# [EPOCH: 30/100, STEP:11/14] loss: 0.401
# [EPOCH: 30/100, STEP:13/14] loss: 0.391
# [EPOCH: 30/100] accuracy: 0.621 val_loss: 2.894
# ---------------------------------------------
# [EPOCH: 31/100, STEP:1/14] loss: 0.194
# [EPOCH: 31/100, STEP:3/14] loss: 0.403
# [EPOCH: 31/100, STEP:5/14] loss: 0.381
# [EPOCH: 31/100, STEP:7/14] loss: 0.389
# [EPOCH: 31/100, STEP:9/14] loss: 0.394
# [EPOCH: 31/100, STEP:11/14] loss: 0.383
# [EPOCH: 31/100, STEP:13/14] loss: 0.385
# [EPOCH: 31/100] accuracy: 0.621 val_loss: 2.885
# ---------------------------------------------
# [EPOCH: 32/100, STEP:1/14] loss: 0.186
# [EPOCH: 32/100, STEP:3/14] loss: 0.396
# [EPOCH: 32/100, STEP:5/14] loss: 0.386
# [EPOCH: 32/100, STEP:7/14] loss: 0.391
# [EPOCH: 32/100, STEP:9/14] loss: 0.406
# [EPOCH: 32/100, STEP:11/14] loss: 0.374
# [EPOCH: 32/100, STEP:13/14] loss: 0.376
# [EPOCH: 32/100] accuracy: 0.621 val_loss: 2.876
# ---------------------------------------------
# [EPOCH: 33/100, STEP:1/14] loss: 0.208
# [EPOCH: 33/100, STEP:3/14] loss: 0.391
# [EPOCH: 33/100, STEP:5/14] loss: 0.385
# [EPOCH: 33/100, STEP:7/14] loss: 0.375
# [EPOCH: 33/100, STEP:9/14] loss: 0.381
# [EPOCH: 33/100, STEP:11/14] loss: 0.383
# [EPOCH: 33/100, STEP:13/14] loss: 0.394
# [EPOCH: 33/100] accuracy: 0.620 val_loss: 2.867
# ---------------------------------------------
# [EPOCH: 34/100, STEP:1/14] loss: 0.195
# [EPOCH: 34/100, STEP:3/14] loss: 0.380
# [EPOCH: 34/100, STEP:5/14] loss: 0.385
# [EPOCH: 34/100, STEP:7/14] loss: 0.392
# [EPOCH: 34/100, STEP:9/14] loss: 0.389
# [EPOCH: 34/100, STEP:11/14] loss: 0.386
# [EPOCH: 34/100, STEP:13/14] loss: 0.388
# [EPOCH: 34/100] accuracy: 0.620 val_loss: 2.859
# ---------------------------------------------
# [EPOCH: 35/100, STEP:1/14] loss: 0.195
# [EPOCH: 35/100, STEP:3/14] loss: 0.405
# [EPOCH: 35/100, STEP:5/14] loss: 0.370
# [EPOCH: 35/100, STEP:7/14] loss: 0.389
# [EPOCH: 35/100, STEP:9/14] loss: 0.405
# [EPOCH: 35/100, STEP:11/14] loss: 0.397
# [EPOCH: 35/100, STEP:13/14] loss: 0.362
# [EPOCH: 35/100] accuracy: 0.620 val_loss: 2.850
# ---------------------------------------------
# [EPOCH: 36/100, STEP:1/14] loss: 0.192
# [EPOCH: 36/100, STEP:3/14] loss: 0.385
# [EPOCH: 36/100, STEP:5/14] loss: 0.389
# [EPOCH: 36/100, STEP:7/14] loss: 0.385
# [EPOCH: 36/100, STEP:9/14] loss: 0.373
# [EPOCH: 36/100, STEP:11/14] loss: 0.397
# [EPOCH: 36/100, STEP:13/14] loss: 0.377
# [EPOCH: 36/100] accuracy: 0.620 val_loss: 2.842
# ---------------------------------------------
# [EPOCH: 37/100, STEP:1/14] loss: 0.197
# [EPOCH: 37/100, STEP:3/14] loss: 0.395
# [EPOCH: 37/100, STEP:5/14] loss: 0.386
# [EPOCH: 37/100, STEP:7/14] loss: 0.388
# [EPOCH: 37/100, STEP:9/14] loss: 0.376
# [EPOCH: 37/100, STEP:11/14] loss: 0.384
# [EPOCH: 37/100, STEP:13/14] loss: 0.377
# [EPOCH: 37/100] accuracy: 0.620 val_loss: 2.834
# ---------------------------------------------
# [EPOCH: 38/100, STEP:1/14] loss: 0.175
# [EPOCH: 38/100, STEP:3/14] loss: 0.394
# [EPOCH: 38/100, STEP:5/14] loss: 0.383
# [EPOCH: 38/100, STEP:7/14] loss: 0.372
# [EPOCH: 38/100, STEP:9/14] loss: 0.380
# [EPOCH: 38/100, STEP:11/14] loss: 0.395
# [EPOCH: 38/100, STEP:13/14] loss: 0.385
# [EPOCH: 38/100] accuracy: 0.620 val_loss: 2.827
# ---------------------------------------------
# [EPOCH: 39/100, STEP:1/14] loss: 0.190
# [EPOCH: 39/100, STEP:3/14] loss: 0.393
# [EPOCH: 39/100, STEP:5/14] loss: 0.397
# [EPOCH: 39/100, STEP:7/14] loss: 0.389
# [EPOCH: 39/100, STEP:9/14] loss: 0.362
# [EPOCH: 39/100, STEP:11/14] loss: 0.369
# [EPOCH: 39/100, STEP:13/14] loss: 0.385
# [EPOCH: 39/100] accuracy: 0.620 val_loss: 2.819
# ---------------------------------------------
# [EPOCH: 40/100, STEP:1/14] loss: 0.189
# [EPOCH: 40/100, STEP:3/14] loss: 0.383
# [EPOCH: 40/100, STEP:5/14] loss: 0.361
# [EPOCH: 40/100, STEP:7/14] loss: 0.390
# [EPOCH: 40/100, STEP:9/14] loss: 0.379
# [EPOCH: 40/100, STEP:11/14] loss: 0.387
# [EPOCH: 40/100, STEP:13/14] loss: 0.379
# [EPOCH: 40/100] accuracy: 0.621 val_loss: 2.812
# ---------------------------------------------
# [EPOCH: 41/100, STEP:1/14] loss: 0.183
# [EPOCH: 41/100, STEP:3/14] loss: 0.389
# [EPOCH: 41/100, STEP:5/14] loss: 0.387
# [EPOCH: 41/100, STEP:7/14] loss: 0.373
# [EPOCH: 41/100, STEP:9/14] loss: 0.395
# [EPOCH: 41/100, STEP:11/14] loss: 0.361
# [EPOCH: 41/100, STEP:13/14] loss: 0.382
# [EPOCH: 41/100] accuracy: 0.621 val_loss: 2.804
# ---------------------------------------------
# [EPOCH: 42/100, STEP:1/14] loss: 0.191
# [EPOCH: 42/100, STEP:3/14] loss: 0.378
# [EPOCH: 42/100, STEP:5/14] loss: 0.369
# [EPOCH: 42/100, STEP:7/14] loss: 0.388
# [EPOCH: 42/100, STEP:9/14] loss: 0.378
# [EPOCH: 42/100, STEP:11/14] loss: 0.379
# [EPOCH: 42/100, STEP:13/14] loss: 0.390
# [EPOCH: 42/100] accuracy: 0.621 val_loss: 2.797
# ---------------------------------------------
# [EPOCH: 43/100, STEP:1/14] loss: 0.182
# [EPOCH: 43/100, STEP:3/14] loss: 0.387
# [EPOCH: 43/100, STEP:5/14] loss: 0.365
# [EPOCH: 43/100, STEP:7/14] loss: 0.388
# [EPOCH: 43/100, STEP:9/14] loss: 0.375
# [EPOCH: 43/100, STEP:11/14] loss: 0.387
# [EPOCH: 43/100, STEP:13/14] loss: 0.376
# [EPOCH: 43/100] accuracy: 0.623 val_loss: 2.790
# ---------------------------------------------
# [EPOCH: 44/100, STEP:1/14] loss: 0.197
# [EPOCH: 44/100, STEP:3/14] loss: 0.381
# [EPOCH: 44/100, STEP:5/14] loss: 0.363
# [EPOCH: 44/100, STEP:7/14] loss: 0.399
# [EPOCH: 44/100, STEP:9/14] loss: 0.399
# [EPOCH: 44/100, STEP:11/14] loss: 0.374
# [EPOCH: 44/100, STEP:13/14] loss: 0.360
# [EPOCH: 44/100] accuracy: 0.624 val_loss: 2.784
# ---------------------------------------------
# [EPOCH: 45/100, STEP:1/14] loss: 0.196
# [EPOCH: 45/100, STEP:3/14] loss: 0.369
# [EPOCH: 45/100, STEP:5/14] loss: 0.365
# [EPOCH: 45/100, STEP:7/14] loss: 0.382
# [EPOCH: 45/100, STEP:9/14] loss: 0.395
# [EPOCH: 45/100, STEP:11/14] loss: 0.381
# [EPOCH: 45/100, STEP:13/14] loss: 0.375
# [EPOCH: 45/100] accuracy: 0.626 val_loss: 2.777
# ---------------------------------------------
# [EPOCH: 46/100, STEP:1/14] loss: 0.186
# [EPOCH: 46/100, STEP:3/14] loss: 0.384
# [EPOCH: 46/100, STEP:5/14] loss: 0.379
# [EPOCH: 46/100, STEP:7/14] loss: 0.374
# [EPOCH: 46/100, STEP:9/14] loss: 0.388
# [EPOCH: 46/100, STEP:11/14] loss: 0.373
# [EPOCH: 46/100, STEP:13/14] loss: 0.383
# [EPOCH: 46/100] accuracy: 0.626 val_loss: 2.770
# ---------------------------------------------
# [EPOCH: 47/100, STEP:1/14] loss: 0.196
# [EPOCH: 47/100, STEP:3/14] loss: 0.374
# [EPOCH: 47/100, STEP:5/14] loss: 0.384
# [EPOCH: 47/100, STEP:7/14] loss: 0.366
# [EPOCH: 47/100, STEP:9/14] loss: 0.382
# [EPOCH: 47/100, STEP:11/14] loss: 0.379
# [EPOCH: 47/100, STEP:13/14] loss: 0.378
# [EPOCH: 47/100] accuracy: 0.627 val_loss: 2.764
# ---------------------------------------------
# [EPOCH: 48/100, STEP:1/14] loss: 0.189
# [EPOCH: 48/100, STEP:3/14] loss: 0.389
# [EPOCH: 48/100, STEP:5/14] loss: 0.380
# [EPOCH: 48/100, STEP:7/14] loss: 0.369
# [EPOCH: 48/100, STEP:9/14] loss: 0.368
# [EPOCH: 48/100, STEP:11/14] loss: 0.377
# [EPOCH: 48/100, STEP:13/14] loss: 0.381
# [EPOCH: 48/100] accuracy: 0.627 val_loss: 2.758
# ---------------------------------------------
# [EPOCH: 49/100, STEP:1/14] loss: 0.176
# [EPOCH: 49/100, STEP:3/14] loss: 0.372
# [EPOCH: 49/100, STEP:5/14] loss: 0.369
# [EPOCH: 49/100, STEP:7/14] loss: 0.387
# [EPOCH: 49/100, STEP:9/14] loss: 0.375
# [EPOCH: 49/100, STEP:11/14] loss: 0.376
# [EPOCH: 49/100, STEP:13/14] loss: 0.381
# [EPOCH: 49/100] accuracy: 0.627 val_loss: 2.752
# ---------------------------------------------
# [EPOCH: 50/100, STEP:1/14] loss: 0.185
# [EPOCH: 50/100, STEP:3/14] loss: 0.374
# [EPOCH: 50/100, STEP:5/14] loss: 0.362
# [EPOCH: 50/100, STEP:7/14] loss: 0.376
# [EPOCH: 50/100, STEP:9/14] loss: 0.382
# [EPOCH: 50/100, STEP:11/14] loss: 0.374
# [EPOCH: 50/100, STEP:13/14] loss: 0.379
# [EPOCH: 50/100] accuracy: 0.629 val_loss: 2.746
# ---------------------------------------------
# [EPOCH: 51/100, STEP:1/14] loss: 0.185
# [EPOCH: 51/100, STEP:3/14] loss: 0.362
# [EPOCH: 51/100, STEP:5/14] loss: 0.389
# [EPOCH: 51/100, STEP:7/14] loss: 0.379
# [EPOCH: 51/100, STEP:9/14] loss: 0.358
# [EPOCH: 51/100, STEP:11/14] loss: 0.369
# [EPOCH: 51/100, STEP:13/14] loss: 0.396
# [EPOCH: 51/100] accuracy: 0.627 val_loss: 2.740
# ---------------------------------------------
# [EPOCH: 52/100, STEP:1/14] loss: 0.195
# [EPOCH: 52/100, STEP:3/14] loss: 0.353
# [EPOCH: 52/100, STEP:5/14] loss: 0.388
# [EPOCH: 52/100, STEP:7/14] loss: 0.393
# [EPOCH: 52/100, STEP:9/14] loss: 0.366
# [EPOCH: 52/100, STEP:11/14] loss: 0.380
# [EPOCH: 52/100, STEP:13/14] loss: 0.353
# [EPOCH: 52/100] accuracy: 0.626 val_loss: 2.734
# ---------------------------------------------
# [EPOCH: 53/100, STEP:1/14] loss: 0.186
# [EPOCH: 53/100, STEP:3/14] loss: 0.394
# [EPOCH: 53/100, STEP:5/14] loss: 0.379
# [EPOCH: 53/100, STEP:7/14] loss: 0.370
# [EPOCH: 53/100, STEP:9/14] loss: 0.358
# [EPOCH: 53/100, STEP:11/14] loss: 0.381
# [EPOCH: 53/100, STEP:13/14] loss: 0.344
# [EPOCH: 53/100] accuracy: 0.627 val_loss: 2.728
# ---------------------------------------------
# [EPOCH: 54/100, STEP:1/14] loss: 0.166
# [EPOCH: 54/100, STEP:3/14] loss: 0.375
# [EPOCH: 54/100, STEP:5/14] loss: 0.368
# [EPOCH: 54/100, STEP:7/14] loss: 0.376
# [EPOCH: 54/100, STEP:9/14] loss: 0.376
# [EPOCH: 54/100, STEP:11/14] loss: 0.365
# [EPOCH: 54/100, STEP:13/14] loss: 0.380
# [EPOCH: 54/100] accuracy: 0.627 val_loss: 2.723
# ---------------------------------------------
# [EPOCH: 55/100, STEP:1/14] loss: 0.182
# [EPOCH: 55/100, STEP:3/14] loss: 0.388
# [EPOCH: 55/100, STEP:5/14] loss: 0.379
# [EPOCH: 55/100, STEP:7/14] loss: 0.365
# [EPOCH: 55/100, STEP:9/14] loss: 0.382
# [EPOCH: 55/100, STEP:11/14] loss: 0.363
# [EPOCH: 55/100, STEP:13/14] loss: 0.357
# [EPOCH: 55/100] accuracy: 0.627 val_loss: 2.717
# ---------------------------------------------
# [EPOCH: 56/100, STEP:1/14] loss: 0.188
# [EPOCH: 56/100, STEP:3/14] loss: 0.369
# [EPOCH: 56/100, STEP:5/14] loss: 0.383
# [EPOCH: 56/100, STEP:7/14] loss: 0.345
# [EPOCH: 56/100, STEP:9/14] loss: 0.378
# [EPOCH: 56/100, STEP:11/14] loss: 0.364
# [EPOCH: 56/100, STEP:13/14] loss: 0.382
# [EPOCH: 56/100] accuracy: 0.626 val_loss: 2.712
# ---------------------------------------------
# [EPOCH: 57/100, STEP:1/14] loss: 0.184
# [EPOCH: 57/100, STEP:3/14] loss: 0.385
# [EPOCH: 57/100, STEP:5/14] loss: 0.355
# [EPOCH: 57/100, STEP:7/14] loss: 0.375
# [EPOCH: 57/100, STEP:9/14] loss: 0.356
# [EPOCH: 57/100, STEP:11/14] loss: 0.382
# [EPOCH: 57/100, STEP:13/14] loss: 0.364
# [EPOCH: 57/100] accuracy: 0.626 val_loss: 2.707
# ---------------------------------------------
# [EPOCH: 58/100, STEP:1/14] loss: 0.182
# [EPOCH: 58/100, STEP:3/14] loss: 0.366
# [EPOCH: 58/100, STEP:5/14] loss: 0.380
# [EPOCH: 58/100, STEP:7/14] loss: 0.370
# [EPOCH: 58/100, STEP:9/14] loss: 0.360
# [EPOCH: 58/100, STEP:11/14] loss: 0.383
# [EPOCH: 58/100, STEP:13/14] loss: 0.353
# [EPOCH: 58/100] accuracy: 0.626 val_loss: 2.702
# ---------------------------------------------
# [EPOCH: 59/100, STEP:1/14] loss: 0.190
# [EPOCH: 59/100, STEP:3/14] loss: 0.366
# [EPOCH: 59/100, STEP:5/14] loss: 0.356
# [EPOCH: 59/100, STEP:7/14] loss: 0.352
# [EPOCH: 59/100, STEP:9/14] loss: 0.356
# [EPOCH: 59/100, STEP:11/14] loss: 0.399
# [EPOCH: 59/100, STEP:13/14] loss: 0.364
# [EPOCH: 59/100] accuracy: 0.626 val_loss: 2.697
# ---------------------------------------------
# [EPOCH: 60/100, STEP:1/14] loss: 0.174
# [EPOCH: 60/100, STEP:3/14] loss: 0.363
# [EPOCH: 60/100, STEP:5/14] loss: 0.358
# [EPOCH: 60/100, STEP:7/14] loss: 0.381
# [EPOCH: 60/100, STEP:9/14] loss: 0.369
# [EPOCH: 60/100, STEP:11/14] loss: 0.359
# [EPOCH: 60/100, STEP:13/14] loss: 0.357
# [EPOCH: 60/100] accuracy: 0.626 val_loss: 2.692
# ---------------------------------------------
# [EPOCH: 61/100, STEP:1/14] loss: 0.185
# [EPOCH: 61/100, STEP:3/14] loss: 0.372
# [EPOCH: 61/100, STEP:5/14] loss: 0.381
# [EPOCH: 61/100, STEP:7/14] loss: 0.368
# [EPOCH: 61/100, STEP:9/14] loss: 0.353
# [EPOCH: 61/100, STEP:11/14] loss: 0.382
# [EPOCH: 61/100, STEP:13/14] loss: 0.350
# [EPOCH: 61/100] accuracy: 0.626 val_loss: 2.687
# ---------------------------------------------
# [EPOCH: 62/100, STEP:1/14] loss: 0.183
# [EPOCH: 62/100, STEP:3/14] loss: 0.372
# [EPOCH: 62/100, STEP:5/14] loss: 0.362
# [EPOCH: 62/100, STEP:7/14] loss: 0.370
# [EPOCH: 62/100, STEP:9/14] loss: 0.373
# [EPOCH: 62/100, STEP:11/14] loss: 0.361
# [EPOCH: 62/100, STEP:13/14] loss: 0.368
# [EPOCH: 62/100] accuracy: 0.626 val_loss: 2.682
# ---------------------------------------------
# [EPOCH: 63/100, STEP:1/14] loss: 0.181
# [EPOCH: 63/100, STEP:3/14] loss: 0.371
# [EPOCH: 63/100, STEP:5/14] loss: 0.388
# [EPOCH: 63/100, STEP:7/14] loss: 0.358
# [EPOCH: 63/100, STEP:9/14] loss: 0.350
# [EPOCH: 63/100, STEP:11/14] loss: 0.350
# [EPOCH: 63/100, STEP:13/14] loss: 0.372
# [EPOCH: 63/100] accuracy: 0.626 val_loss: 2.678
# ---------------------------------------------
# [EPOCH: 64/100, STEP:1/14] loss: 0.167
# [EPOCH: 64/100, STEP:3/14] loss: 0.359
# [EPOCH: 64/100, STEP:5/14] loss: 0.392
# [EPOCH: 64/100, STEP:7/14] loss: 0.358
# [EPOCH: 64/100, STEP:9/14] loss: 0.365
# [EPOCH: 64/100, STEP:11/14] loss: 0.362
# [EPOCH: 64/100, STEP:13/14] loss: 0.369
# [EPOCH: 64/100] accuracy: 0.626 val_loss: 2.673
# ---------------------------------------------
# [EPOCH: 65/100, STEP:1/14] loss: 0.182
# [EPOCH: 65/100, STEP:3/14] loss: 0.356
# [EPOCH: 65/100, STEP:5/14] loss: 0.381
# [EPOCH: 65/100, STEP:7/14] loss: 0.368
# [EPOCH: 65/100, STEP:9/14] loss: 0.359
# [EPOCH: 65/100, STEP:11/14] loss: 0.347
# [EPOCH: 65/100, STEP:13/14] loss: 0.366
# [EPOCH: 65/100] accuracy: 0.626 val_loss: 2.669
# ---------------------------------------------
# [EPOCH: 66/100, STEP:1/14] loss: 0.184
# [EPOCH: 66/100, STEP:3/14] loss: 0.375
# [EPOCH: 66/100, STEP:5/14] loss: 0.353
# [EPOCH: 66/100, STEP:7/14] loss: 0.372
# [EPOCH: 66/100, STEP:9/14] loss: 0.370
# [EPOCH: 66/100, STEP:11/14] loss: 0.362
# [EPOCH: 66/100, STEP:13/14] loss: 0.362
# [EPOCH: 66/100] accuracy: 0.626 val_loss: 2.664
# ---------------------------------------------
# [EPOCH: 67/100, STEP:1/14] loss: 0.189
# [EPOCH: 67/100, STEP:3/14] loss: 0.367
# [EPOCH: 67/100, STEP:5/14] loss: 0.378
# [EPOCH: 67/100, STEP:7/14] loss: 0.362
# [EPOCH: 67/100, STEP:9/14] loss: 0.360
# [EPOCH: 67/100, STEP:11/14] loss: 0.362
# [EPOCH: 67/100, STEP:13/14] loss: 0.355
# [EPOCH: 67/100] accuracy: 0.626 val_loss: 2.660
# ---------------------------------------------
# [EPOCH: 68/100, STEP:1/14] loss: 0.179
# [EPOCH: 68/100, STEP:3/14] loss: 0.366
# [EPOCH: 68/100, STEP:5/14] loss: 0.381
# [EPOCH: 68/100, STEP:7/14] loss: 0.364
# [EPOCH: 68/100, STEP:9/14] loss: 0.369
# [EPOCH: 68/100, STEP:11/14] loss: 0.360
# [EPOCH: 68/100, STEP:13/14] loss: 0.350
# [EPOCH: 68/100] accuracy: 0.626 val_loss: 2.656
# ---------------------------------------------
# [EPOCH: 69/100, STEP:1/14] loss: 0.180
# [EPOCH: 69/100, STEP:3/14] loss: 0.359
# [EPOCH: 69/100, STEP:5/14] loss: 0.367
# [EPOCH: 69/100, STEP:7/14] loss: 0.345
# [EPOCH: 69/100, STEP:9/14] loss: 0.350
# [EPOCH: 69/100, STEP:11/14] loss: 0.365
# [EPOCH: 69/100, STEP:13/14] loss: 0.376
# [EPOCH: 69/100] accuracy: 0.626 val_loss: 2.651
# ---------------------------------------------
# [EPOCH: 70/100, STEP:1/14] loss: 0.181
# [EPOCH: 70/100, STEP:3/14] loss: 0.347
# [EPOCH: 70/100, STEP:5/14] loss: 0.356
# [EPOCH: 70/100, STEP:7/14] loss: 0.384
# [EPOCH: 70/100, STEP:9/14] loss: 0.352
# [EPOCH: 70/100, STEP:11/14] loss: 0.382
# [EPOCH: 70/100, STEP:13/14] loss: 0.356
# [EPOCH: 70/100] accuracy: 0.626 val_loss: 2.647
# ---------------------------------------------
# [EPOCH: 71/100, STEP:1/14] loss: 0.170
# [EPOCH: 71/100, STEP:3/14] loss: 0.363
# [EPOCH: 71/100, STEP:5/14] loss: 0.369
# [EPOCH: 71/100, STEP:7/14] loss: 0.379
# [EPOCH: 71/100, STEP:9/14] loss: 0.358
# [EPOCH: 71/100, STEP:11/14] loss: 0.349
# [EPOCH: 71/100, STEP:13/14] loss: 0.350
# [EPOCH: 71/100] accuracy: 0.626 val_loss: 2.643
# ---------------------------------------------
# [EPOCH: 72/100, STEP:1/14] loss: 0.177
# [EPOCH: 72/100, STEP:3/14] loss: 0.379
# [EPOCH: 72/100, STEP:5/14] loss: 0.358
# [EPOCH: 72/100, STEP:7/14] loss: 0.353
# [EPOCH: 72/100, STEP:9/14] loss: 0.361
# [EPOCH: 72/100, STEP:11/14] loss: 0.375
# [EPOCH: 72/100, STEP:13/14] loss: 0.361
# [EPOCH: 72/100] accuracy: 0.626 val_loss: 2.639
# ---------------------------------------------
# [EPOCH: 73/100, STEP:1/14] loss: 0.170
# [EPOCH: 73/100, STEP:3/14] loss: 0.372
# [EPOCH: 73/100, STEP:5/14] loss: 0.366
# [EPOCH: 73/100, STEP:7/14] loss: 0.375
# [EPOCH: 73/100, STEP:9/14] loss: 0.345
# [EPOCH: 73/100, STEP:11/14] loss: 0.356
# [EPOCH: 73/100, STEP:13/14] loss: 0.365
# [EPOCH: 73/100] accuracy: 0.626 val_loss: 2.635
# ---------------------------------------------
# [EPOCH: 74/100, STEP:1/14] loss: 0.168
# [EPOCH: 74/100, STEP:3/14] loss: 0.372
# [EPOCH: 74/100, STEP:5/14] loss: 0.382
# [EPOCH: 74/100, STEP:7/14] loss: 0.348
# [EPOCH: 74/100, STEP:9/14] loss: 0.363
# [EPOCH: 74/100, STEP:11/14] loss: 0.362
# [EPOCH: 74/100, STEP:13/14] loss: 0.356
# [EPOCH: 74/100] accuracy: 0.626 val_loss: 2.632
# ---------------------------------------------
# [EPOCH: 75/100, STEP:1/14] loss: 0.184
# [EPOCH: 75/100, STEP:3/14] loss: 0.362
# [EPOCH: 75/100, STEP:5/14] loss: 0.356
# [EPOCH: 75/100, STEP:7/14] loss: 0.378
# [EPOCH: 75/100, STEP:9/14] loss: 0.361
# [EPOCH: 75/100, STEP:11/14] loss: 0.345
# [EPOCH: 75/100, STEP:13/14] loss: 0.359
# [EPOCH: 75/100] accuracy: 0.626 val_loss: 2.628
# ---------------------------------------------
# [EPOCH: 76/100, STEP:1/14] loss: 0.188
# [EPOCH: 76/100, STEP:3/14] loss: 0.362
# [EPOCH: 76/100, STEP:5/14] loss: 0.365
# [EPOCH: 76/100, STEP:7/14] loss: 0.363
# [EPOCH: 76/100, STEP:9/14] loss: 0.333
# [EPOCH: 76/100, STEP:11/14] loss: 0.362
# [EPOCH: 76/100, STEP:13/14] loss: 0.391
# [EPOCH: 76/100] accuracy: 0.626 val_loss: 2.624
# ---------------------------------------------
# [EPOCH: 77/100, STEP:1/14] loss: 0.166
# [EPOCH: 77/100, STEP:3/14] loss: 0.352
# [EPOCH: 77/100, STEP:5/14] loss: 0.372
# [EPOCH: 77/100, STEP:7/14] loss: 0.356
# [EPOCH: 77/100, STEP:9/14] loss: 0.370
# [EPOCH: 77/100, STEP:11/14] loss: 0.369
# [EPOCH: 77/100, STEP:13/14] loss: 0.358
# [EPOCH: 77/100] accuracy: 0.626 val_loss: 2.621
# ---------------------------------------------
# [EPOCH: 78/100, STEP:1/14] loss: 0.184
# [EPOCH: 78/100, STEP:3/14] loss: 0.370
# [EPOCH: 78/100, STEP:5/14] loss: 0.346
# [EPOCH: 78/100, STEP:7/14] loss: 0.354
# [EPOCH: 78/100, STEP:9/14] loss: 0.342
# [EPOCH: 78/100, STEP:11/14] loss: 0.375
# [EPOCH: 78/100, STEP:13/14] loss: 0.383
# [EPOCH: 78/100] accuracy: 0.626 val_loss: 2.617
# ---------------------------------------------
# [EPOCH: 79/100, STEP:1/14] loss: 0.183
# [EPOCH: 79/100, STEP:3/14] loss: 0.342
# [EPOCH: 79/100, STEP:5/14] loss: 0.387
# [EPOCH: 79/100, STEP:7/14] loss: 0.358
# [EPOCH: 79/100, STEP:9/14] loss: 0.360
# [EPOCH: 79/100, STEP:11/14] loss: 0.366
# [EPOCH: 79/100, STEP:13/14] loss: 0.354
# [EPOCH: 79/100] accuracy: 0.626 val_loss: 2.614
# ---------------------------------------------
# [EPOCH: 80/100, STEP:1/14] loss: 0.192
# [EPOCH: 80/100, STEP:3/14] loss: 0.395
# [EPOCH: 80/100, STEP:5/14] loss: 0.350
# [EPOCH: 80/100, STEP:7/14] loss: 0.360
# [EPOCH: 80/100, STEP:9/14] loss: 0.371
# [EPOCH: 80/100, STEP:11/14] loss: 0.318
# [EPOCH: 80/100, STEP:13/14] loss: 0.363
# [EPOCH: 80/100] accuracy: 0.626 val_loss: 2.610
# ---------------------------------------------
# [EPOCH: 81/100, STEP:1/14] loss: 0.199
# [EPOCH: 81/100, STEP:3/14] loss: 0.362
# [EPOCH: 81/100, STEP:5/14] loss: 0.358
# [EPOCH: 81/100, STEP:7/14] loss: 0.336
# [EPOCH: 81/100, STEP:9/14] loss: 0.365
# [EPOCH: 81/100, STEP:11/14] loss: 0.355
# [EPOCH: 81/100, STEP:13/14] loss: 0.360
# [EPOCH: 81/100] accuracy: 0.626 val_loss: 2.607
# ---------------------------------------------
# [EPOCH: 82/100, STEP:1/14] loss: 0.176
# [EPOCH: 82/100, STEP:3/14] loss: 0.366
# [EPOCH: 82/100, STEP:5/14] loss: 0.344
# [EPOCH: 82/100, STEP:7/14] loss: 0.367
# [EPOCH: 82/100, STEP:9/14] loss: 0.357
# [EPOCH: 82/100, STEP:11/14] loss: 0.356
# [EPOCH: 82/100, STEP:13/14] loss: 0.358
# [EPOCH: 82/100] accuracy: 0.626 val_loss: 2.604
# ---------------------------------------------
# [EPOCH: 83/100, STEP:1/14] loss: 0.187
# [EPOCH: 83/100, STEP:3/14] loss: 0.333
# [EPOCH: 83/100, STEP:5/14] loss: 0.361
# [EPOCH: 83/100, STEP:7/14] loss: 0.369
# [EPOCH: 83/100, STEP:9/14] loss: 0.393
# [EPOCH: 83/100, STEP:11/14] loss: 0.327
# [EPOCH: 83/100, STEP:13/14] loss: 0.358
# [EPOCH: 83/100] accuracy: 0.626 val_loss: 2.600
# ---------------------------------------------
# [EPOCH: 84/100, STEP:1/14] loss: 0.177
# [EPOCH: 84/100, STEP:3/14] loss: 0.374
# [EPOCH: 84/100, STEP:5/14] loss: 0.353
# [EPOCH: 84/100, STEP:7/14] loss: 0.372
# [EPOCH: 84/100, STEP:9/14] loss: 0.347
# [EPOCH: 84/100, STEP:11/14] loss: 0.339
# [EPOCH: 84/100, STEP:13/14] loss: 0.352
# [EPOCH: 84/100] accuracy: 0.626 val_loss: 2.597
# ---------------------------------------------
# [EPOCH: 85/100, STEP:1/14] loss: 0.153
# [EPOCH: 85/100, STEP:3/14] loss: 0.389
# [EPOCH: 85/100, STEP:5/14] loss: 0.354
# [EPOCH: 85/100, STEP:7/14] loss: 0.347
# [EPOCH: 85/100, STEP:9/14] loss: 0.355
# [EPOCH: 85/100, STEP:11/14] loss: 0.362
# [EPOCH: 85/100, STEP:13/14] loss: 0.350
# [EPOCH: 85/100] accuracy: 0.626 val_loss: 2.594
# ---------------------------------------------
# [EPOCH: 86/100, STEP:1/14] loss: 0.163
# [EPOCH: 86/100, STEP:3/14] loss: 0.366
# [EPOCH: 86/100, STEP:5/14] loss: 0.349
# [EPOCH: 86/100, STEP:7/14] loss: 0.363
# [EPOCH: 86/100, STEP:9/14] loss: 0.395
# [EPOCH: 86/100, STEP:11/14] loss: 0.357
# [EPOCH: 86/100, STEP:13/14] loss: 0.344
# [EPOCH: 86/100] accuracy: 0.626 val_loss: 2.591
# ---------------------------------------------
# [EPOCH: 87/100, STEP:1/14] loss: 0.182
# [EPOCH: 87/100, STEP:3/14] loss: 0.358
# [EPOCH: 87/100, STEP:5/14] loss: 0.357
# [EPOCH: 87/100, STEP:7/14] loss: 0.359
# [EPOCH: 87/100, STEP:9/14] loss: 0.329
# [EPOCH: 87/100, STEP:11/14] loss: 0.397
# [EPOCH: 87/100, STEP:13/14] loss: 0.331
# [EPOCH: 87/100] accuracy: 0.626 val_loss: 2.588
# ---------------------------------------------
# [EPOCH: 88/100, STEP:1/14] loss: 0.181
# [EPOCH: 88/100, STEP:3/14] loss: 0.373
# [EPOCH: 88/100, STEP:5/14] loss: 0.338
# [EPOCH: 88/100, STEP:7/14] loss: 0.364
# [EPOCH: 88/100, STEP:9/14] loss: 0.365
# [EPOCH: 88/100, STEP:11/14] loss: 0.347
# [EPOCH: 88/100, STEP:13/14] loss: 0.349
# [EPOCH: 88/100] accuracy: 0.626 val_loss: 2.585
# ---------------------------------------------
# [EPOCH: 89/100, STEP:1/14] loss: 0.194
# [EPOCH: 89/100, STEP:3/14] loss: 0.354
# [EPOCH: 89/100, STEP:5/14] loss: 0.336
# [EPOCH: 89/100, STEP:7/14] loss: 0.355
# [EPOCH: 89/100, STEP:9/14] loss: 0.345
# [EPOCH: 89/100, STEP:11/14] loss: 0.399
# [EPOCH: 89/100, STEP:13/14] loss: 0.330
# [EPOCH: 89/100] accuracy: 0.626 val_loss: 2.582
# ---------------------------------------------
# [EPOCH: 90/100, STEP:1/14] loss: 0.176
# [EPOCH: 90/100, STEP:3/14] loss: 0.356
# [EPOCH: 90/100, STEP:5/14] loss: 0.340
# [EPOCH: 90/100, STEP:7/14] loss: 0.360
# [EPOCH: 90/100, STEP:9/14] loss: 0.340
# [EPOCH: 90/100, STEP:11/14] loss: 0.387
# [EPOCH: 90/100, STEP:13/14] loss: 0.358
# [EPOCH: 90/100] accuracy: 0.626 val_loss: 2.579
# ---------------------------------------------
# [EPOCH: 91/100, STEP:1/14] loss: 0.194
# [EPOCH: 91/100, STEP:3/14] loss: 0.339
# [EPOCH: 91/100, STEP:5/14] loss: 0.349
# [EPOCH: 91/100, STEP:7/14] loss: 0.351
# [EPOCH: 91/100, STEP:9/14] loss: 0.389
# [EPOCH: 91/100, STEP:11/14] loss: 0.345
# [EPOCH: 91/100, STEP:13/14] loss: 0.353
# [EPOCH: 91/100] accuracy: 0.626 val_loss: 2.576
# ---------------------------------------------
# [EPOCH: 92/100, STEP:1/14] loss: 0.168
# [EPOCH: 92/100, STEP:3/14] loss: 0.385
# [EPOCH: 92/100, STEP:5/14] loss: 0.351
# [EPOCH: 92/100, STEP:7/14] loss: 0.356
# [EPOCH: 92/100, STEP:9/14] loss: 0.359
# [EPOCH: 92/100, STEP:11/14] loss: 0.348
# [EPOCH: 92/100, STEP:13/14] loss: 0.351
# [EPOCH: 92/100] accuracy: 0.626 val_loss: 2.573
# ---------------------------------------------
# [EPOCH: 93/100, STEP:1/14] loss: 0.187
# [EPOCH: 93/100, STEP:3/14] loss: 0.343
# [EPOCH: 93/100, STEP:5/14] loss: 0.359
# [EPOCH: 93/100, STEP:7/14] loss: 0.377
# [EPOCH: 93/100, STEP:9/14] loss: 0.360
# [EPOCH: 93/100, STEP:11/14] loss: 0.344
# [EPOCH: 93/100, STEP:13/14] loss: 0.337
# [EPOCH: 93/100] accuracy: 0.626 val_loss: 2.571
# ---------------------------------------------
# [EPOCH: 94/100, STEP:1/14] loss: 0.182
# [EPOCH: 94/100, STEP:3/14] loss: 0.343
# [EPOCH: 94/100, STEP:5/14] loss: 0.351
# [EPOCH: 94/100, STEP:7/14] loss: 0.353
# [EPOCH: 94/100, STEP:9/14] loss: 0.357
# [EPOCH: 94/100, STEP:11/14] loss: 0.370
# [EPOCH: 94/100, STEP:13/14] loss: 0.353
# [EPOCH: 94/100] accuracy: 0.624 val_loss: 2.568
# ---------------------------------------------
# [EPOCH: 95/100, STEP:1/14] loss: 0.173
# [EPOCH: 95/100, STEP:3/14] loss: 0.352
# [EPOCH: 95/100, STEP:5/14] loss: 0.348
# [EPOCH: 95/100, STEP:7/14] loss: 0.374
# [EPOCH: 95/100, STEP:9/14] loss: 0.343
# [EPOCH: 95/100, STEP:11/14] loss: 0.354
# [EPOCH: 95/100, STEP:13/14] loss: 0.368
# [EPOCH: 95/100] accuracy: 0.624 val_loss: 2.565
# ---------------------------------------------
# [EPOCH: 96/100, STEP:1/14] loss: 0.180
# [EPOCH: 96/100, STEP:3/14] loss: 0.344
# [EPOCH: 96/100, STEP:5/14] loss: 0.355
# [EPOCH: 96/100, STEP:7/14] loss: 0.351
# [EPOCH: 96/100, STEP:9/14] loss: 0.359
# [EPOCH: 96/100, STEP:11/14] loss: 0.353
# [EPOCH: 96/100, STEP:13/14] loss: 0.373
# [EPOCH: 96/100] accuracy: 0.624 val_loss: 2.563
# ---------------------------------------------
# [EPOCH: 97/100, STEP:1/14] loss: 0.185
# [EPOCH: 97/100, STEP:3/14] loss: 0.348
# [EPOCH: 97/100, STEP:5/14] loss: 0.384
# [EPOCH: 97/100, STEP:7/14] loss: 0.362
# [EPOCH: 97/100, STEP:9/14] loss: 0.331
# [EPOCH: 97/100, STEP:11/14] loss: 0.353
# [EPOCH: 97/100, STEP:13/14] loss: 0.355
# [EPOCH: 97/100] accuracy: 0.624 val_loss: 2.560
# ---------------------------------------------
# [EPOCH: 98/100, STEP:1/14] loss: 0.188
# [EPOCH: 98/100, STEP:3/14] loss: 0.360
# [EPOCH: 98/100, STEP:5/14] loss: 0.374
# [EPOCH: 98/100, STEP:7/14] loss: 0.360
# [EPOCH: 98/100, STEP:9/14] loss: 0.332
# [EPOCH: 98/100, STEP:11/14] loss: 0.357
# [EPOCH: 98/100, STEP:13/14] loss: 0.339
# [EPOCH: 98/100] accuracy: 0.624 val_loss: 2.557
# ---------------------------------------------
# [EPOCH: 99/100, STEP:1/14] loss: 0.170
# [EPOCH: 99/100, STEP:3/14] loss: 0.381
# [EPOCH: 99/100, STEP:5/14] loss: 0.314
# [EPOCH: 99/100, STEP:7/14] loss: 0.369
# [EPOCH: 99/100, STEP:9/14] loss: 0.362
# [EPOCH: 99/100, STEP:11/14] loss: 0.358
# [EPOCH: 99/100, STEP:13/14] loss: 0.355
# [EPOCH: 99/100] accuracy: 0.624 val_loss: 2.555
# ---------------------------------------------
# [EPOCH: 100/100, STEP:1/14] loss: 0.177
# [EPOCH: 100/100, STEP:3/14] loss: 0.357
# [EPOCH: 100/100, STEP:5/14] loss: 0.352
# [EPOCH: 100/100, STEP:7/14] loss: 0.369
# [EPOCH: 100/100, STEP:9/14] loss: 0.354
# [EPOCH: 100/100, STEP:11/14] loss: 0.351
# [EPOCH: 100/100, STEP:13/14] loss: 0.341
# [EPOCH: 100/100] accuracy: 0.624 val_loss: 2.552
# ---------------------------------------------

# %% [markdown]
# ## Evaluate on test dataset

# %%
correct_predictions = 0
for sentences, labels in test:
  class_scores = model(sentences)
  correct_predictions +=(torch.argmax(class_scores, dim=1) == labels).sum()
accuracy = correct_predictions/(len(test.dataset))
print(f"Test accuracy: {accuracy:.2%}")
# Out:
# Test accuracy: 67.33%
